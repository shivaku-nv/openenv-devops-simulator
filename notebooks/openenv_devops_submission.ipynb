# %% [markdown]
# # OpenEnv DevOps Submission Notebook
#
# This notebook is a lightweight Colab entrypoint for the hackathon submission. It installs the repo, runs the local reward-evidence generator, and shows the main verification commands.

# %%
# !git clone https://github.com/shivaku-nv/openenv-devops-simulator.git
# %cd openenv-devops-simulator
# !python3 -m pip install -U pip
# !python3 -m pip install -e .

# %%
# !python3 evaluation/generate_reward_evidence.py
# !sed -n '1,200p' outputs/reward_evidence/README.md

# %%
# !python3 inference.py
